# %%
# import packages
from __future__ import print_function
import pandas as pd
import numpy as np

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
# loading data right from the source:
death_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
country_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv')

# %%
death_df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/13/21  7/14/21  7/15/21  \
# 0        0        0        0        0  ...     5791     5923     5983
# 1        0        0        0        0  ...     2456     2456     2456
# 2        0        0        0        0  ...     3867     3882     3895
# 3        0        0        0        0  ...      127      127      127
# 4        0        0        0        0  ...      941      946      951
#
#    7/16/21  7/17/21  7/18/21  7/19/21  7/20/21  7/21/21  7/22/21
# 0     5983     5983     5983     6213     6266     6266     6325
# 1     2456     2456     2456     2456     2456     2456     2456
# 2     3910     3922     3938     3956     3979     3994     4008
# 3      127      127      127      127      127      127      127
# 4      952      954      957      969      970      973      977
#
# [5 rows x 552 columns]

# %%
country_df.head()
# Out:
#   Country_Region          Last_Update       Lat      Long_  Confirmed  Deaths  \
# 0    Afghanistan  2021-07-23 14:21:42  33.93911  67.709953   143183.0  6325.0
# 1        Albania  2021-07-23 14:21:42  41.15330  20.168300   132797.0  2456.0
# 2        Algeria  2021-07-23 14:21:42  28.03390   1.659600   158213.0  4008.0
# 3        Andorra  2021-07-23 14:21:42  42.50630   1.521800    14464.0   127.0
# 4         Angola  2021-07-23 14:21:42 -11.20270  17.873900    41405.0   977.0
#
#    Recovered   Active  Incident_Rate  People_Tested  People_Hospitalized  \
# 0    82586.0  54272.0     367.811718            NaN                  NaN
# 1   130109.0    232.0    4614.531934            NaN                  NaN
# 2   108537.0  45668.0     360.796435            NaN                  NaN
# 3    13988.0    349.0   18719.989646            NaN                  NaN
# 4    35082.0   5346.0     125.980230            NaN                  NaN
#
#    Mortality_Rate  UID ISO3
# 0        4.417424    4  AFG
# 1        1.849439    8  ALB
# 2        2.533294   12  DZA
# 3        0.878042   20  AND
# 4        2.359618   24  AGO

# %%
# data cleaning - renaming the df column to lower case
country_df.columns = map(str.lower, country_df.columns)
recovered_df.columns=map(str.lower, recovered_df.columns)
death_df.columns=map(str.lower, death_df.columns)
confirmed_df.columns=map(str.lower, confirmed_df.columns)

# %%
# changing province/state to state and country/region to country
confirmed_df = confirmed_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
recovered_df = confirmed_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
death_df = death_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
country_df = country_df.rename(columns={'country_region': 'country'})

# %%
sorted_country_df = country_df.sort_values('confirmed',ascending=False)

# %%
sorted_country_df
# Out:
#               country          last_update        lat      long_   confirmed  \
# 181                US  2021-07-23 14:21:42  40.000000 -100.00000  34286314.0
# 79              India  2021-07-23 14:21:42  20.593684   78.96288  31293062.0
# 23             Brazil  2021-07-23 14:21:42 -14.235000  -51.92530  19523711.0
# 144            Russia  2021-07-23 14:21:42  61.524000  105.31880   6002303.0
# 62             France  2021-07-23 14:21:42  46.227600    2.21370   5996060.0
# ..                ...                  ...        ...        ...         ...
# 112  Marshall Islands  2021-07-23 14:21:42   7.131500  171.18450         4.0
# 149             Samoa  2021-07-23 14:21:42 -13.759000 -172.10460         3.0
# 91           Kiribati  2021-07-23 14:21:42  -3.370400 -168.73400         2.0
# 116        Micronesia  2021-07-23 14:21:42   7.425600  150.55080         1.0
# 134             Palau  2021-07-23 14:21:42   7.515000  134.58250         0.0
#
#        deaths   recovered     active  incident_rate  people_tested  \
# 181  610204.0         NaN        NaN   10406.623005            NaN
# 79   419470.0  30468079.0   405513.0    2267.605983            NaN
# 23   547016.0  17470332.0  1506363.0    9185.060822            NaN
# 144  149796.0   5384350.0   468157.0    4113.012787            NaN
# 62   111749.0    410035.0  5474124.0    9186.053908            NaN
# ..        ...         ...        ...            ...            ...
# 112       0.0         4.0        0.0       6.847791            NaN
# 149       0.0         3.0        0.0       1.529598            NaN
# 91        0.0         NaN        2.0       1.700594            NaN
# 116       0.0         1.0        0.0       0.878619            NaN
# 134       0.0         NaN        0.0       0.000000            NaN
#
#      people_hospitalized  mortality_rate  uid iso3
# 181                  NaN        1.779731  840  USA
# 79                   NaN        1.340457  356  IND
# 23                   NaN        2.801803   76  BRA
# 144                  NaN        2.495642  643  RUS
# 62                   NaN        1.863707  250  FRA
# ..                   ...             ...  ...  ...
# 112                  NaN        0.000000  584  MHL
# 149                  NaN        0.000000  882  WSM
# 91                   NaN        0.000000  296  KIR
# 116                  NaN        0.000000  583  FSM
# 134                  NaN             NaN  585  PLW
#
# [195 rows x 14 columns]

# %%
def highlight_col(x):
    r = 'backgroud-color: red'
    p = 'background-color: purple'
    g = 'background-color: grey'
    temp_df = pd.DataFrame('', index=x.index, columns = x.columns)
    temp_df.iloc[:,4] = p
    temp_df.iloc[:,5] = r
    temp_df.iloc[:,6] = g
    return temp_df
sorted_country_df.style.apply(highlight_col, axis=None)
# Out:
# <style  type="text/css" >
# #T_d099d_row0_col4,#T_d099d_row1_col4,#T_d099d_row2_col4,#T_d099d_row3_col4,#T_d099d_row4_col4,#T_d099d_row5_col4,#T_d099d_row6_col4,#T_d099d_row7_col4,#T_d099d_row8_col4,#T_d099d_row9_col4,#T_d099d_row10_col4,#T_d099d_row11_col4,#T_d099d_row12_col4,#T_d099d_row13_col4,#T_d099d_row14_col4,#T_d099d_row15_col4,#T_d099d_row16_col4,#T_d099d_row17_col4,#T_d099d_row18_col4,#T_d099d_row19_col4,#T_d099d_row20_col4,#T_d099d_row21_col4,#T_d099d_row22_col4,#T_d099d_row23_col4,#T_d099d_row24_col4,#T_d099d_row25_col4,#T_d099d_row26_col4,#T_d099d_row27_col4,#T_d099d_row28_col4,#T_d099d_row29_col4,#T_d099d_row30_col4,#T_d099d_row31_col4,#T_d099d_row32_col4,#T_d099d_row33_col4,#T_d099d_row34_col4,#T_d099d_row35_col4,#T_d099d_row36_col4,#T_d099d_row37_col4,#T_d099d_row38_col4,#T_d099d_row39_col4,#T_d099d_row40_col4,#T_d099d_row41_col4,#T_d099d_row42_col4,#T_d099d_row43_col4,#T_d099d_row44_col4,#T_d099d_row45_col4,#T_d099d_row46_col4,#T_d099d_row47_col4,#T_d099d_row48_col4,#T_d099d_row49_col4,#T_d099d_row50_col4,#T_d099d_row51_col4,#T_d099d_row52_col4,#T_d099d_row53_col4,#T_d099d_row54_col4,#T_d099d_row55_col4,#T_d099d_row56_col4,#T_d099d_row57_col4,#T_d099d_row58_col4,#T_d099d_row59_col4,#T_d099d_row60_col4,#T_d099d_row61_col4,#T_d099d_row62_col4,#T_d099d_row63_col4,#T_d099d_row64_col4,#T_d099d_row65_col4,#T_d099d_row66_col4,#T_d099d_row67_col4,#T_d099d_row68_col4,#T_d099d_row69_col4,#T_d099d_row70_col4,#T_d099d_row71_col4,#T_d099d_row72_col4,#T_d099d_row73_col4,#T_d099d_row74_col4,#T_d099d_row75_col4,#T_d099d_row76_col4,#T_d099d_row
d_row129_col5,#T_d099d_row130_col5,#T_d099d_row131_col5,#T_d099d_row132_col5,#T_d099d_row133_col5,#T_d099d_row134_col5,#T_d099d_row135_col5,#T_d099d_row136_col5,#T_d099d_row137_col5,#T_d099d_row138_col5,#T_d099d_row139_col5,#T_d099d_row140_col5,#T_d099d_row141_col5,#T_d099d_row142_col5,#T_d099d_row143_col5,#T_d099d_row144_col5,#T_d099d_row145_col5,#T_d099d_row146_col5,#T_d099d_row147_col5,#T_d099d_row148_col5,#T_d099d_row149_col5,#T_d099d_row150_col5,#T_d099d_row151_col5,#T_d099d_row152_col5,#T_d099d_row153_col5,#T_d099d_row154_col5,#T_d099d_row155_col5,#T_d099d_row156_col5,#T_d099d_row157_col5,#T_d099d_row158_col5,#T_d099d_row159_col5,#T_d099d_row160_col5,#T_d099d_row161_col5,#T_d099d_row162_col5,#T_d099d_row163_col5,#T_d099d_row164_col5,#T_d099d_row165_col5,#T_d099d_row166_col5,#T_d099d_row167_col5,#T_d099d_row168_col5,#T_d099d_row169_col5,#T_d099d_row170_col5,#T_d099d_row171_col5,#T_d099d_row172_col5,#T_d099d_row173_col5,#T_d099d_row174_col5,#T_d099d_row175_col5,#T_d099d_row176_col5,#T_d099d_row177_col5,#T_d099d_row178_col5,#T_d099d_row179_col5,#T_d099d_row180_col5,#T_d099d_row181_col5,#T_d099d_row182_col5,#T_d099d_row183_col5,#T_d099d_row184_col5,#T_d099d_row185_col5,#T_d099d_row186_col5,#T_d099d_row187_col5,#T_d099d_row188_col5,#T_d099d_row189_col5,#T_d099d_row190_col5,#T_d099d_row191_col5,#T_d099d_row192_co

# %%
import pandas as pd
import plotly.express as px

# %%
fig = px.scatter(sorted_country_df.head(10), x='country', y='confirmed', size='confirmed',color='country', hover_name='country',size_max=60)
fig.update_layout()
fig.show()
# Out:
# <div>                            <div id="fbccfb31-980c-4f8a-aa9f-13e46f727965" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbccfb31-980c-4f8a-aa9f-13e46f727965")) {                    Plotly.newPlot(                        "fbccfb31-980c-4f8a-aa9f-13e46f727965",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}<extra></extra>","hovertext":["US"],"legendgroup":"US","marker":{"color":"#636efa","size":[34286314.0],"sizemode":"area","sizeref":9523.976111111111,"symbol":"circle"},"mode":"markers","name":"US","orientation":"v","showlegend":true,"type":"scatter","x":["US"],"xaxis":"x","y":[34286314.0],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}<extra></extra>","hovertext":["India"],"legendgroup":"India","marker":{"color":"#EF553B","size":[31293062.0],"sizemode":"area","sizeref":9523.976111111111,"symbol":"circle"},"mode":"markers","name":"India","orientation":"v","showlegend":true,"type":"scatter","x":["India"],"xaxis":"x","y":[31293062.0],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}<extra></extra>","hovertext":["Brazil"],"legendgroup":"Brazil","marker":{"color":"#00cc96","size":[19523711.0],"sizemode":"area","sizeref":9523.976111111111,"symbol":"circle"},"mode":"markers","name":"Brazil","orientation":"v","showlegend":true,"type":"scatter","x":["Brazil"],"xaxis":"x","y":[19523711.0],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}<extra></extra>","hovertext":["Russia"],"legendgroup":"Russia","marker":{"color":"#ab63fa","size":[6002303.0],"sizemode":"area","sizeref":9523.976111111111,"symbol":"circle"},"mode":"markers","name":"Russia","orientation":"v","showlegend":true,"type":"scatter","x":["Russia"],"xaxis":"x","y":[6002303.0],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}<extra></extra>","hovertext":["France"],"legendgroup":"France","marker":{"color":"#FFA15A","size":[5996060.0],"sizemode":"area","sizeref":9523.976111111111,"symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"type":"scatter","x":["France"],"xaxis":"x","y":[5996060.0],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}<extra></extra>","hovertext":["United Kingdom"],"legendgroup":"United Kingdom","marker":{"color":"#19d3f3","size":[5626772.0],"sizemode":"area","sizeref":9523.976111111111,"symbol":"circle"},"mode":"markers","name":"United Kingdom","orientation":"v","showlegend":true,"type":"scatter","x":["United Kingdom"],"xaxis":"x","y":[5626772.0],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}<extra></extra>","hovertext":["Turkey"],"legendgroup":"Turkey","marker":{"color":"#FF6692","size":[5563903.0],"sizemode":"area","sizeref":9523.976111111111,"symbol":"circle"},"mode":"markers","name":"Turkey","orientation":"v","showlegend":true,"type":"scatter","x":["Turkey"],"xaxis":"x","y":[5563903.0],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}<extra></extra>","hovertext":["Argentina"],"legendgroup":"Argentina","marker":{"color":"#B6E880","size":[4812351.0],"sizemode":"area","sizeref":9523.976111111111,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"type":"scatter","x":["Argentina"],"xaxis":"x","y":[4812351.0],"yaxis":"y"},{"hovertemplate":"<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}<extra></extra>","hovertext":["Colombia"],"legendgroup":"Colombia","marker":{"color":"#FF97FF","size":[4692570.0],"sizemode":"area","sizer ...

# %%
import plotly.graph_objects as go
def plot_cases_for_country(country):
    labels = ['confirmed', 'deaths']
    colors = ['blue', 'red']
    mode_size = [6,8]
    line_size = [4,5]

    df_list = [confirmed_df, death_df]

    fig = go.Figure()
 
    for i, df in enumerate(df_list):
        if country == 'World' or country =='world':
            x_data = np.array(list(df.iloc[:, 5:].columns))
            y_data = np.sum(np.asarray(df.iloc[:, 5:]), axis=0)
            
        else:
            x_data = np.array(list(df.iloc[:, 5:].columns))
            y_data = np.sum(np.asarray(df[df['country']==country].iloc[:,5:]), axis=0)
            
        fig.add_trace(go.Scatter(x=x_data, y=y_data, mode='lines+markers',
                                name=labels[i],
                                line=dict(color=colors[i], width=line_size[i]),
                                connectgaps=True,
                                text='Total' + str(labels[i]) + ":"+ str(y_data[-1])
                                ))
        fig.show()
#plot_cases_for_country('India')

interact(plot_cases_for_country, country='World');
# Out:
# interactive(children=(Text(value='World', description='country'), Output()), _dom_classes=('widget-interact',)…

# %%
confirmed_df
# Out:
#     state             country        lat        long  1/22/20  1/23/20  \
# 0     NaN         Afghanistan  33.939110   67.709953        0        0
# 1     NaN             Albania  41.153300   20.168300        0        0
# 2     NaN             Algeria  28.033900    1.659600        0        0
# 3     NaN             Andorra  42.506300    1.521800        0        0
# 4     NaN              Angola -11.202700   17.873900        0        0
# ..    ...                 ...        ...         ...      ...      ...
# 274   NaN             Vietnam  14.058324  108.277199        0        2
# 275   NaN  West Bank and Gaza  31.952200   35.233200        0        0
# 276   NaN               Yemen  15.552727   48.516388        0        0
# 277   NaN              Zambia -13.133897   27.849332        0        0
# 278   NaN            Zimbabwe -19.015438   29.154857        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  7/13/21  7/14/21  7/15/21  \
# 0          0        0        0        0  ...   134653   136643   137853
# 1          0        0        0        0  ...   132608   132616   132629
# 2          0        0        0        0  ...   147883   148797   149906
# 3          0        0        0        0  ...    14167    14167    14239
# 4          0        0        0        0  ...    40138    40327    40530
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 274        2        2        2        2  ...    35409    38239    42288
# 275        0        0        0        0  ...   315224   315409   315504
# 276        0        0        0        0  ...     6961     6964     6967
# 277        0        0        0        0  ...   178748   180549   182129
# 278        0        0        0        0  ...    73271    76381    78872
#
#      7/16/21  7/17/21  7/18/21  7/19/21  7/20/21  7/21/21  7/22/21
# 0     137853   137853   137853   141489   142414   142414   143183
# 1     132647   132665   132686   132697   132740   132763   132797
# 2     151103   152210   153309   154486   155784   157005   158213
# 3      14273    14273    14273    14359    14379    14379    14464
# 4      40631    40707    40805    40906    41061    41227    41405
# ..       ...      ...      ...      ...      ...      ...      ...
# 274    46292    51002    55845    60180    65607    71144    78269
# 275   315504   315641   315641   315761   315761   315876   315876
# 276     6972     6977     6981     6987     6992     6997     7001
# 277   183344   184672   185649   186279   187602   188573   189731
# 278    81168    82613    83619    85732    88415    91120    93421
#
# [279 rows x 552 columns]

# %%
confirmed_df=confirmed_df.dropna(subset = ["lat","long"])

# %%
import folium

# %%
world_map = folium.Map(location=[11,0], tiles="cartodbpositron", zoom_start=2, max_zoom = 6, min_zoom = 2)


for i in range(0,len(confirmed_df)):
    folium.Circle(
        location=[confirmed_df.iloc[i]['lat'], confirmed_df.iloc[i]['long']],
        fill=True,
        radius=(int((np.log(confirmed_df.iloc[i,-1]+1.00001)))+0.2)*50000,
        color='red',
        fill_color='indigo',
        tooltip = "<div style='margin: 0; background-color: black; color: white;'>"+
                    "<h4 style='text-align:center;font-weight: bold'>"+confirmed_df.iloc[i]['country'] + "</h4>"
                    "<hr style='margin:10px;color: white;'>"+
                    "<ul style='color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px'>"+
                        "<li>Confirmed: "+str(confirmed_df.iloc[i,-1])+"</li>"+
                        "<li>Deaths:   "+str(death_df.iloc[i,-1])+"</li>"+
                        "<li>Death Rate: "+ str(np.round(death_df.iloc[i,-1]/(confirmed_df.iloc[i,-1]+1.00001)*100,2))+ "</li>"+
                    "</ul></div>",
        ).add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_54899c7fd1af4294a9649ce72074c356%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_54899c7fd1af4294a9649ce72074c356%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_54899c7fd1af4294a9649ce72074c356%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_54899c7fd1af4294a9649ce72074c356%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B11.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...
